# %% [markdown]
# # Trump Rally Text Analysis
# #### **Descriptions:** This is an NLP (Natural Language Processing) Analysis of Donald Trump Presidential Rally Speech. This analysis is intended for educational purposes only with no political intentions whatsoever.
#
# ### Author: Mohammad Adi Amirudin (amirudin.adi@gmail.com)
# ### Initial Date: Aug, 17th 2021
# ### Dataset: Trump Rally Speech from Kaggle (https://www.kaggle.com/christianlillelund/donald-trumps-rallies)
# ### Method: Time Series, NLP (Sentiment Analysis, Segmentation, Topic Modeling), EDA
# ### Tools: Ms.Visual Studio Code IDE (Python 3.9.6 on Jupyter Notebook)
# ### Interpreter & Package: miniconda | mininlp (pandas numpy matplotlib seaborn nltk scikit-learn notebook textblob gensim wordcloud levensthein)

# %% [markdown]
# # Import Libraries & Dataset

# %%
import nltk as nltk
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import spacy as sp

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import NMF  
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans
from sklearn.metrics import mean_absolute_error,silhouette_score
from gensim.parsing.preprocessing import remove_stopwords
from wordcloud import WordCloud
from wordcloud import WordCloud,STOPWORDS
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment import vader
from nltk.tokenize import RegexpTokenizer
from nltk.util import ngrams
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk import word_tokenize
from scipy import stats
from heapq import nlargest

sns.set_style('darkgrid')

# %% [markdown]
# ## Importing Trump Rally Speech Text Corpora

# %%
corpus = []          
for dirname, _, filenames in os.walk("Trump_Rally_Speech_Text_Corpora/"):
    for filename in filenames:
        with open((os.path.join(dirname, filename)), encoding="UTF-8") as file_input: corpus.append(file_input.read(),)

# %%
place_name = [i.replace(".txt"," ") for i in filenames]
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
place, month_list, date = [],[],[]
for name in place_name:
    index= -1
    for month in months:
        index =name.find(month)
        if index != -1:
            month_list.append(month)
            break
    place.append(name[:index])
    date.append(name[index+3:])

# %%
trump_df = pd.DataFrame({"Month":month_list,"Year":date,"Place":place,"Speech":corpus})
trump_df[['Day','Year']] = trump_df.Year.str.split("_",expand=True,)

# %%
trump_df["Place"] = trump_df["Place"].str.replace( r"([A-Z])", r" \1").str.strip()
trump_df["Place"] = trump_df["Place"].replace("Winston- Salem", "Winston-Salem")
trump_df.head(5)
# Out:
# C:\Users\Addi\AppData\Local\Temp/ipykernel_8420/490486357.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   trump_df["Place"] = trump_df["Place"].str.replace( r"([A-Z])", r" \1").str.strip()
#   Month   Year         Place  \
# 0   Dec  2019   Battle Creek
# 1   Sep  2020        Bemidji
# 2   Feb  2020     Charleston
# 3   Mar  2020      Charlotte
# 4   Aug  2019     Cincinnati
#
#                                               Speech Day
# 0  Thank you. Thank you. Thank you to Vice Presid...  19
# 1  There's a lot of people. That's great. Thank y...  18
# 2  Thank you. Thank you. Thank you. All I can say...  28
# 3  I want to thank you very much. North Carolina,...   2
# 4  Thank you all. Thank you very much. Thank you ...   1

# %%
trump_df["State"] = ['Mississippi','Minnesota','Ohio','Michigan','New Hampshire','Nevada','New Jersey','Texas','Iowa','North Carolina','Michigan','Kentucky','Wisconsin','Arizona',
                       'Oklahoma','Minnesota','New Hampshire','Pennsylvania','Colorado','Pennsylvania','Ohio','South Carolina','North Carolina','Nevada','North Carolina','New Hampshire',
                       'North Carolina','Ohio','Texas','Wisconsin','Nevada','South Carolina','New Mexico','Arizona','Pennsylvania']
trump_df.head(5)
# Out:
#   Month   Year         Place  \
# 0   Dec  2019   Battle Creek
# 1   Sep  2020        Bemidji
# 2   Feb  2020     Charleston
# 3   Mar  2020      Charlotte
# 4   Aug  2019     Cincinnati
#
#                                               Speech Day          State
# 0  Thank you. Thank you. Thank you to Vice Presid...  19    Mississippi
# 1  There's a lot of people. That's great. Thank y...  18      Minnesota
# 2  Thank you. Thank you. Thank you. All I can say...  28           Ohio
# 3  I want to thank you very much. North Carolina,...   2       Michigan
# 4  Thank you all. Thank you very much. Thank you ...   1  New Hampshire

# %% [markdown]
# ## Importing States & Cities Selected Metrics

# %%
metrics1_df = pd.read_csv("other data.csv",keep_default_na=False, na_values=[""])
metrics1_df.head(5)
# Out:
#    Row Labels  State millenials population percentage (25 - 34)  \
# 0     Alabama                                              13.0
# 1      Alaska                                              16.1
# 2     Arizona                                              13.8
# 3    Arkansas                                              12.8
# 4  California                                              15.3
#
#    State late adult population percentage (55-64)  \
# 0                                            13.3
# 1                                            13.0
# 2                                            12.1
# 3                                            12.8
# 4                                            12.1
#
#    State adult Tertiary Education Rate (25+ years old)   \
# 0                                               29.8
# 1                                               34.6
# 2                                               33.7
# 3                                               29.3
# 4                                               28.4
#
#    State unemployment Rate (16+ years old)  \
# 0                                      4.9
# 1                                      5.8
# 2                                      5.1
# 3                                      4.8
# 4                                      5.1
#
#    State percentage of management, business, science, and arts  workers (16+ years old)  \
# 0                                               35.9
# 1                                               38.3
# 2                                               37.9
# 3                                               33.9
# 4                                               40.7
#
#    State percentage of natural resources, construction, and maintenance workers (16+ years old)  \
# 0                                                9.4
# 1                                               11.4
# 2                                                9.5
# 3                                               10.1
# 4                                                9.0
#
#    State percentage of production, transportation, and material moving workers  \
# 0                                               17.9
# 1                                               13.4
# 2                                               11.2
# 3                                               18.3
# 4                                               11.9
#
#    State percentage of manufacturing workers (16+ years old)  \
# 0                                               14.5
# 1                                                4.2
# 2                                                7.0
# 3                                               13.8
# 4                                                8.7
#
#    State percentage of agriculture, forestry, fishing and hunting, and mining workers (16+ years old)  \
# 0                                                1.2
# 1                                                4.9
# 2                                                1.4
# 3                                                2.8
# 4                                                2.1
#
#    State percentage of professional, scientific, and management, and administrative and waste management services workers (16+ years old)  \
# 0                                                9.6
# 1                                                8.9
# 2                                               12.5
# 3                                                7.5
# 4                                               14.2
#
#    State percentage of finance and insurance, and real estate and rental and leasing workers (16+ years old)  \
# 0                                                5.6
# 1                                                4.3
# 2                                                8.7
# 3                                                4.6
# 4                                                5.8
#
#    State inflation-adjusted average household income (2019)  \
# 0                                            51734.0
# 1                                            75463.0
# 2                                            62055.0
# 3                                            48952.0
# 4                                            80440.0
#
#    State household percentage with cash public assistance as income(2019)  \
# 0                                                1.4
# 1                                                6.0
# 2                                                1.5
# 3                                                2.2
# 4                                                2.8
#
#    States poverty rate (percent of population)
# 0                                         15.5
# 1                                         10.1
# 2                                         13.5
# 3                                         16.2
# 4                                         11.8

# %%
metrics2_df = pd.read_csv("Race Data.csv",keep_default_na=False, na_values=[""])
metrics2_df.head(5)
# Out:
#         State  WhiteTotalPerc  BlackTotalPerc  IndianTotalPerc  \
# 0     Alabama          0.6809          0.2664           0.0052
# 1      Alaska          0.6458          0.0328           0.1489
# 2     Arizona          0.7722          0.0450           0.0450
# 3    Arkansas          0.7672          0.1532           0.0068
# 4  California          0.5970          0.0579           0.0077
#
#    AsianTotalPerc  HawaiianTotalPerc  OtherTotalPerc
# 0          0.0136             0.0005          0.0334
# 1          0.0623             0.0125          0.0976
# 2          0.0331             0.0021          0.1026
# 3          0.0152             0.0029          0.0547
# 4          0.1449             0.0040          0.1885

# %% [markdown]
# ## Combining The Dataset

# %%
merged_inner1 = pd.merge(left=trump_df, right=metrics1_df, left_on="State", right_on="Row Labels")
merged_inner1.head(5)
# Out:
#   Month   Year         Place  \
# 0   Dec  2019   Battle Creek
# 1   Sep  2020        Bemidji
# 2   Sep  2020        Latrobe
# 3   Feb  2020     Charleston
# 4   Sep  2020        Mosinee
#
#                                               Speech Day        State  \
# 0  Thank you. Thank you. Thank you to Vice Presid...  19  Mississippi
# 1  There's a lot of people. That's great. Thank y...  18    Minnesota
# 2  So thank you Pennsylvania, very much. I'm thri...   3    Minnesota
# 3  Thank you. Thank you. Thank you. All I can say...  28         Ohio
# 4  Thank you, thank you very much. Thank you very...  17         Ohio
#
#     Row Labels  State millenials population percentage (25 - 34)  \
# 0  Mississippi                                              12.4
# 1    Minnesota                                              13.6
# 2    Minnesota                                              13.6
# 3         Ohio                                              13.2
# 4         Ohio                                              13.2
#
#    State late adult population percentage (55-64)  \
# 0                                            12.9
# 1                                            13.4
# 2                                            13.4
# 3                                            13.7
# 4                                            13.7
#
#    State adult Tertiary Education Rate (25+ years old)   ...  \
# 0                                               32.8     ...
# 1                                               31.9     ...
# 2                                               31.9     ...
# 3                                               28.9     ...
# 4                                               28.9     ...
#
#    State percentage of management, business, science, and arts  workers (16+ years old)  \
# 0                                               32.8
# 1                                               42.8
# 2                                               42.8
# 3                                               38.1
# 4                                               38.1
#
#    State percentage of natural resources, construction, and maintenance workers (16+ years old)  \
# 0                                               10.4
# 1                                                7.9
# 2                                                7.9
# 3                                                7.6
# 4                                                7.6
#
#    State percentage of production, transportation, and material moving workers  \
# 0                                               18.3
# 1                                               13.9
# 2                                               13.9
# 3                                               16.9
# 4                                               16.9
#
#    State percentage of manufacturing workers (16+ years old)  \
# 0                                               13.5
# 1                                               13.4
# 2                                               13.4
# 3                                               15.3
# 4                                               15.3
#
#    State percentage of agriculture, forestry, fishing and hunting, and mining workers (16+ years old)  \
# 0                                                2.2
# 1                                                2.1
# 2                                                2.1
# 3                                                0.9
# 4                                                0.9
#
#    State percentage of professional, scientific, and management, and administrative and waste management services workers (16+ years old)  \
# 0                                                6.6
# 1                                               10.1
# 2                                               10.1
# 3                                                9.8
# 4                                                9.8
#
#    State percentage of finance and insurance, and real estate and rental and leasing workers (16+ years old)  \
# 0                                                4.7
# 1                                                7.1
# 2                                                7.1
# 3                                                6.2
# 4                                                6.2
#
#    State inflation-adjusted average household income (2019)  \
# 0                                            45792.0
# 1                                            74593.0
# 2                                            74593.0
# 3                                            58642.0
# 4                                            58642.0
#
#    State household percentage with cash public assistance as income(2019)  \
# 0                                                1.8
# 1                                                3.0
# 2                                                3.0
# 3                                                2.4
# 4                                                2.4
#
#    States poverty rate (percent of population)
# 0                                         19.6
# 1                                          9.0
# 2                                          9.0
# 3                                         13.1
# 4                                         13.1
#
# [5 rows x 21 columns]

# %%
merged_inner2 = pd.merge(left=merged_inner1, right=metrics2_df, left_on="State", right_on="State")
rally_df = merged_inner2.drop("Row Labels", axis = 1)
rally_df.head(5)
# Out:
#   Month   Year         Place  \
# 0   Dec  2019   Battle Creek
# 1   Sep  2020        Bemidji
# 2   Sep  2020        Latrobe
# 3   Feb  2020     Charleston
# 4   Sep  2020        Mosinee
#
#                                               Speech Day        State  \
# 0  Thank you. Thank you. Thank you to Vice Presid...  19  Mississippi
# 1  There's a lot of people. That's great. Thank y...  18    Minnesota
# 2  So thank you Pennsylvania, very much. I'm thri...   3    Minnesota
# 3  Thank you. Thank you. Thank you. All I can say...  28         Ohio
# 4  Thank you, thank you very much. Thank you very...  17         Ohio
#
#    State millenials population percentage (25 - 34)  \
# 0                                              12.4
# 1                                              13.6
# 2                                              13.6
# 3                                              13.2
# 4                                              13.2
#
#    State late adult population percentage (55-64)  \
# 0                                            12.9
# 1                                            13.4
# 2                                            13.4
# 3                                            13.7
# 4                                            13.7
#
#    State adult Tertiary Education Rate (25+ years old)   \
# 0                                               32.8
# 1                                               31.9
# 2                                               31.9
# 3                                               28.9
# 4                                               28.9
#
#    State unemployment Rate (16+ years old)  ...  \
# 0                                      6.6  ...
# 1                                      3.2  ...
# 2                                      3.2  ...
# 3                                      4.6  ...
# 4                                      4.6  ...
#
#    State percentage of finance and insurance, and real estate and rental and leasing workers (16+ years old)  \
# 0                                                4.7
# 1                                                7.1
# 2                                                7.1
# 3                                                6.2
# 4                                                6.2
#
#    State inflation-adjusted average household income (2019)  \
# 0                                            45792.0
# 1                                            74593.0
# 2                                            74593.0
# 3                                            58642.0
# 4                                            58642.0
#
#    State household percentage with cash public assistance as income(2019)  \
# 0                                                1.8
# 1                                                3.0
# 2                                                3.0
# 3                                                2.4
# 4                                                2.4
#
#    States poverty rate (percent of population)  WhiteTotalPerc  \
# 0                                         19.6          0.5841
# 1                                          9.0          0.8285
# 2                                          9.0          0.8285
# 3                                         13.1          0.8130
# 4                                         13.1          0.8130
#
#    BlackTotalPerc  IndianTotalPerc  AsianTotalPerc  HawaiianTotalPerc  \
# 0          0.3772           0.0048          0.0099             0.0002
# 1          0.0641           0.0104          0.0482             0.0004
# 2          0.0641           0.0104          0.0482             0.0004
# 3          0.1241           0.0020          0.0222             0.0003
# 4          0.1241           0.0020          0.0222             0.0003
#
#    OtherTotalPerc
# 0          0.0238
# 1          0.0484
# 2          0.0484
# 3          0.0385
# 4          0.0385
#
# [5 rows x 26 columns]

# %% [markdown]
# # Extracting Text Features & Dataset Preprocessing
#
# ## Preprocessing:
#
# > Stopwords removal
#
# > Tokenization
#
# > Regular Expression

# %% [markdown]
# ## Tokenization

# %%
rally_df["Speech"] = rally_df["Speech"].apply(lambda x: re.sub(r'\[.*?\]','',x))
rally_df["Speech"] = rally_df["Speech"].apply(lambda x: x.lower())
tokenizer = RegexpTokenizer("[a-z][a-z]+[a-z]")

# %%
def nltk_tag_to_wordnet_tag(nltk_tag):
    if nltk_tag.startswith("J"):
        return wordnet.ADJ
    elif nltk_tag.startswith("V"):
        return wordnet.VERB
    elif nltk_tag.startswith("N"):
        return wordnet.NOUN
    elif nltk_tag.startswith("R"):
        return wordnet.ADV
    else:          
        return None

# %%
def lemmatize_sentence(sentence):
     tokenizer = RegexpTokenizer('[a-z][a-z]+[a-z]')
     nltk_tagged = nltk.pos_tag(tokenizer.tokenize(sentence))  
     wordnet_tagged = map(lambda x: (x[0], nltk_tag_to_wordnet_tag(x[1])), nltk_tagged)
     lemmatized_sentence = []
     for word, tag in wordnet_tagged:
         if tag is None:
             lemmatized_sentence.append(word)
         else:        
             lemmatized_sentence.append(WordNetLemmatizer().lemmatize(word, tag))
     return " ".join(lemmatized_sentence)

# %%
def lexical_diversity(text):
    return (len(text) / len(set(text))/10000)

# %%
rally_df["Speech"] = rally_df["Speech"].apply(lambda x: lemmatize_sentence(x))

# %% [markdown]
# ## Stopword Removal

# %%
rally_df["Speech_No_Stopwords"] = rally_df["Speech"].apply(lambda x: remove_stopwords(x))

# %% [markdown]
# ## Text Feature Extractions

# %%
rally_df["Numbers Of Words"] = rally_df["Speech"].apply(lambda x: len(x.split(" ")))
rally_df["Numbers Of StopWords"] = rally_df["Speech"].apply(lambda x: len([word for word in x.split(" ") if word in list(STOPWORDS)]))
rally_df["Numbers Of Sentences"] = rally_df["Speech"].apply(lambda x: len(re.findall("\.",x)))
rally_df["Average Word Length"] = rally_df["Speech"].apply(lambda x: np.mean(np.array([len(va) for va in x.split(" ") if va not in list(STOPWORDS)])))
rally_df["Speech"] = rally_df["Speech"].apply(lambda x: re.sub(r"[,.;@#?!&$]+", " ", x))
rally_df["Lexical Diversity"] = rally_df["Speech"].apply(lambda x: lexical_diversity(x))

# %% [markdown]
# ## Sentiment Analysis

# %%
sid = SentimentIntensityAnalyzer()
rally_df["Sentiments"] = rally_df["Speech_No_Stopwords"].apply(lambda x: sid.polarity_scores(x))
rally_df["Positive Sentiment"] = rally_df["Sentiments"].apply(lambda x: x["pos"]) 
rally_df["Neutral Sentiment"] = rally_df["Sentiments"].apply(lambda x: x["neu"])
rally_df["Negative Sentiment"] = rally_df["Sentiments"].apply(lambda x: x["neg"])
rally_df.drop(columns=["Sentiments"],inplace=True)

# %% [markdown]
# ## Misc Data Extractions

# %%
nlpspacy = sp.load("en_core_web_sm")
rally_df["Numbers of Different Countries Mentioned"] = rally_df["Speech"].apply(lambda x: len([tok for tok in cool_extractor(x).ents if tok.label_ == "GPE" ]))
rally_df["Numbers of Times Money Was Mentioned"] = rally_df["Speech"].apply(lambda x: len([tok for tok in cool_extractor(x).ents if tok.label_ == "MONEY" ]))
rally_df["Numbers of Different People Mentioned"] = rally_df["Speech"].apply(lambda x: len([tok for tok in cool_extractor(x).ents if tok.label_ == "PERSON" ]))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8420/1789616356.py in <module>
# ----> 1 nlpspacy = sp.load("en_core_web_sm")
#       2 rally_df["Numbers of Different Countries Mentioned"] = rally_df["Speech"].apply(lambda x: len([tok for tok in cool_extractor(x).ents if tok.label_ == "GPE" ]))
#       3 rally_df["Numbers of Times Money Was Mentioned"] = rally_df["Speech"].apply(lambda x: len([tok for tok in cool_extractor(x).ents if tok.label_ == "MONEY" ]))
#       4 rally_df["Numbers of Different People Mentioned"] = rally_df["Speech"].apply(lambda x: len([tok for tok in cool_extractor(x).ents if tok.label_ == "PERSON" ]))
#
# ~\miniconda3\envs\mininlp\lib\site-packages\spacy\__init__.py in load(name, vocab, disable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# ~\miniconda3\envs\mininlp\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     329     if name in OLD_MODEL_SHORTCUTS:
#     330         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))
# --> 331     raise IOError(Errors.E050.format(name=name))
#     332
#     333
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.
